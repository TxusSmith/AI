# %%
import random
class HelloGenetic:
    def __init__(self, params):
        self.ALL_CHARACTERS = list("qwertyuiopasdfghjklñzxcvbnm QWERTYUIOPASDFGHJKLÑZXCVBNM1234567890,.;:|°!#$%&/=?¡")
        self.HELLO_WORLD = list("Hello, world!")
        self.params = params
        self.specimen = [None] * self.params["generation_size"]
        
        self.create_initial_population()
        
    def create_initial_population(self):
        self.specimen = list(
            map(lambda _:random.sample(self.ALL_CHARACTERS, len(self.HELLO_WORLD)), self.specimen)
        )
        
    def fitness(self, specimen):
        return sum(1 for expected, actual in zip(self.HELLO_WORLD, specimen) if actual == expected) / len(self.HELLO_WORLD)
        
    def is_converged(self):
        if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
            return True
        return False
    
    def fitness_all(self):
        return list(map(self.fitness, self.specimen))
    
    def selected_specimen(self, specimen_evaluations):
        specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))
        
        specimen_and_evaluations.sort(key=lambda e: e[1], reverse=True)
        
        n_top = int(self.params["select_top"])
        
        return list(map(lambda e: e[0], specimen_and_evaluations[:n_top])) #[:2] ==> slice
    
    def mutate(self, specimen):
        n_characters = int(self.params["mutation_percentage"] * len(specimen))
        
        character_indexes = random.sample(list(range(len(specimen))), n_characters)
        
        mutated = specimen[:]
        
        for idx in character_indexes:
            mutated[idx] = random.choice(self.ALL_CHARACTERS)
            
        return mutated
    
    def generate_children(self, selected_specimen):
        mutated_specimen = [None] * self.params["generation_size"]
        
        for i in range(len(mutated_specimen)):
            mutated_specimen[i] = self.mutate(random.choice(selected_specimen))
            
        return mutated_specimen
    
    def get_fit(self):
        evaluations = self.fitness_all()
        
        max_evaluation = max(evaluations)
        
        max_idx = evaluations.index(max_evaluation)
        
        return self.specimen[max_idx], max_evaluation
    
    def run(self):
        generation_number = 1
        
        while generation_number <= self.params["max_generations"] and not self.is_converged():
            
            top_generation = self.get_fit()
            top_str = "".join(top_generation[0])
            
            print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")
            
            specimen_evaluations = self.fitness_all()
            selected_specimen = self.selected_specimen(specimen_evaluations)
            
            self.specimen = self.generate_children(selected_specimen)
            generation_number += 1
        
        return self.get_fit()

# %%
params = {
    "max_generations":200,
    "generation_size":20,
    "mutation_percentage":0.1,
    "select_top":1,
    "fit_threshold":1
}

hello = HelloGenetic(params)
hello.run()
# Out:
# Generation #1:	°:l$nSsfUoWzK	0.07692307692307693
# Generation #2:	°:l$nSsfYoWzK	0.07692307692307693
# Generation #3:	°:l$oSsfYoWzK	0.15384615384615385
# Generation #4:	°:l/oSsfYoWzK	0.15384615384615385
# Generation #5:	°:l/oGsfYoWzK	0.15384615384615385
# Generation #6:	°:l/oGsfioWzK	0.15384615384615385
# Generation #7:	°:l/oGsfioWzi	0.15384615384615385
# Generation #8:	 :l/oGsfioWzi	0.15384615384615385
# Generation #9:	ñ:l/oGsfioWzi	0.15384615384615385
# Generation #10:	ñ:l/oGKfioWzi	0.15384615384615385
# Generation #11:	ñel/oGKfioWzi	0.23076923076923078
# Generation #12:	ñelloGKfioWzi	0.3076923076923077
# Generation #13:	ñelloGKf/oWzi	0.3076923076923077
# Generation #14:	ñelloGKf/rWzi	0.38461538461538464
# Generation #15:	ñelloGKfPrWzi	0.38461538461538464
# Generation #16:	ñelloGKuPrWzi	0.38461538461538464
# Generation #17:	ñelloGKuPrWzi	0.38461538461538464
# Generation #18:	nelloGKuPrWzi	0.38461538461538464
# Generation #19:	nelloGKuJrWzi	0.38461538461538464
# Generation #20:	#elloGKuJrWzi	0.38461538461538464
# Generation #21:	#elloGKuJrWzñ	0.38461538461538464
# Generation #22:	#elloYKuJrWzñ	0.38461538461538464
# Generation #23:	pelloYKuJrWzñ	0.38461538461538464
# Generation #24:	/elloYKuJrWzñ	0.38461538461538464
# Generation #25:	/ello3KuJrWzñ	0.38461538461538464
# Generation #26:	/ello3KuJrWzw	0.38461538461538464
# Generation #27:	/ello3KwJrWzw	0.46153846153846156
# Generation #28:	/elloqKwJrWzw	0.46153846153846156
# Generation #29:	/elloqKwJrWz0	0.46153846153846156
# Generation #30:	/elloqKw%rWz0	0.46153846153846156
# Generation #31:	/ellosKw%rWz0	0.46153846153846156
# Generation #32:	/ellosKw%rW:0	0.46153846153846156
# Generation #33:	/ellosKwFrW:0	0.46153846153846156
# Generation #34:	/ellosKwFrW:e	0.46153846153846156
# Generation #35:	NellosKwFrW:e	0.46153846153846156
# Generation #36:	NellosKwFrWqe	0.46153846153846156
# Generation #37:	NellosKwFrJqe	0.46153846153846156
# Generation #38:	NellofKwFrJqe	0.46153846153846156
# Generation #39:	NellofKwFr¡qe	0.46153846153846156
# Generation #40:	HellofKwFr¡qe	0.5384615384615384
# Generation #41:	HellofKwFrLqe	0.5384615384615384
# Generation #42:	HellofKwprLqe	0.5384615384615384
# Generation #43:	HellofKwpr:qe	0.5384615384615384
# Generation #44:	HellofKwpr:q!	0.6153846153846154
# Generation #45:	HellofKw%r:q!	0.6153846153846154
# Generation #46:	HellofKw|r:q!	0.6153846153846154
# Generation #47:	HellofKw|r:M!	0.6153846153846154
# Generation #48:	Hellof;w|r:M!	0.6153846153846154
# Generation #49:	Hellof;w|r;M!	0.6153846153846154
# Generation #50:	Hellof;w|r;j!	0.6153846153846154
# Generation #51:	Hellof6w|r;j!	0.6153846153846154
# Generation #52:	Hellof3w|r;j!	0.6153846153846154
# Generation #53:	Hellof3w|r;B!	0.6153846153846154
# Generation #54:	Hellof3w|rlB!	0.6923076923076923
# Generation #55:	Hellof,w|rlB!	0.6923076923076923
# Generation #56:	Hellof9w|rlB!	0.6923076923076923
# Generation #57:	Hellof|w|rlB!	0.6923076923076923
# Generation #58:	Hellof|wPrlB!	0.6923076923076923
# Generation #59:	Hellof|wPrlB!	0.6923076923076923
# Generation #60:	Hellof|wPrlv!	0.6923076923076923
# Generation #61:	Hello:|wPrlv!	0.6923076923076923
# Generation #62:	Hello:|w4rlv!	0.6923076923076923
# Generation #63:	Hello:|w4rlv!	0.6923076923076923
# Generation #64:	Helloñ|w4rlv!	0.6923076923076923
# Generation #65:	Helloñ;w4rlv!	0.6923076923076923
# Generation #66:	Helloñ;w4rlA!	0.6923076923076923
# Generation #67:	Helloñ;w4rld!	0.7692307692307693
# Generation #68:	Helloñ;w8rld!	0.7692307692307693
# Generation #69:	Helloñ;w6rld!	0.7692307692307693
# Generation #70:	Helloñ2w6rld!	0.7692307692307693
# Generation #71:	HelloM2w6rld!	0.7692307692307693
# Generation #72:	HelloM6w6rld!	0.7692307692307693
# Generation #73:	Hellou6w6rld!	0.7692307692307693
# Generation #74:	HelloI6w6rld!	0.7692307692307693
# Generation #75:	HelloI6world!	0.8461538461538461
# Generation #76:	HelloT6world!	0.8461538461538461
# Generation #77:	HellwT6world!	0.7692307692307693
# Generation #78:	HellwT#world!	0.7692307692307693
# Generation #79:	HellwH#world!	0.7692307692307693
# Generation #80:	HellwH world!	0.8461538461538461
# Generation #81:	HellwZ world!	0.8461538461538461
# Generation #82:	Hellw, world!	0.9230769230769231
# Generation #83:	Hellb, world!	0.9230769230769231
# Generation #84:	Helld, world!	0.9230769230769231
# Generation #85:	Hell1, world!	0.9230769230769231
# Generation #86:	Hellh, world!	0.9230769230769231
# Generation #87:	Hellh, world!	0.9230769230769231
# Generation #88:	Hellp, world!	0.9230769230769231
# Generation #89:	Hellp, world!	0.9230769230769231
# Generation #90:	Helly, world!	0.9230769230769231
# Generation #91:	Helly, world!	0.9230769230769231
# Generation #92:	HellI, world!	0.9230769230769231
# Generation #93:	Hellb, world!	0.9230769230769231
# Generation #94:	Hell#, world!	0.9230769230769231
# Generation #95:	Hell°, world!	0.9230769230769231
# (['H', 'e', 'l', 'l', 'o', ',', ' ', 'w', 'o', 'r', 'l', 'd', '!'], 1.0)
